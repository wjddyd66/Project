# %%
import torch
from Model.Skin_Cancer_Model.Skin_Cancer_Model import Model

# %% [markdown]
# ### Load Model

# %%
model = Model()
model.load_state_dict(torch.load('./PreTrainModel/final_model.pt'))

model.eval()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/checkpoints/densenet121-a639ec97.pth
#   0%|          | 0.00/30.8M [00:00<?, ?B/s]
# Model(
#   (seg_model): ResNetUNet(
#     (base_model): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ### Check Model & Output

# %%
input_path = './Dataset/Train/ISIC_0026152.jpg'
save_path = './result.jpg'

model(input_path, save_path)
